# %%
import numpy as np
import pandas as pd

# %%
restaurants = pd.read_csv('/content/sample_data/Swiggy_Nagpur.csv')

# %%
restaurants.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                             Category  Rating  Cost for two  \
# 0  Biryani,Mughlai,Kebabs,Hyderabadi,North Indian...     4.1           600
# 1                            Sweets,Bakery,Beverages     4.6           300
# 2                               North Indian,Chinese     3.3           200
# 3  Biryani,Mughlai,Lucknowi,Hyderabadi,Kebabs,Nor...     3.9           500
# 4                                North Indian,Indian     4.0           300
#
#                 Area                       Locality  \
# 0         Khare Town                     Dharampeth
# 1          Sitabuldi                      SITABULDI
# 2           Loha Pul                 Loha Pul, Pind
# 3              Sadar  Azad Chowk, Near Gandhi Chowk
# 4  Ganeshpeth Colony                     Gandhibagh
#
#                                              Address    Veg  \
# 0  Commercial First Floor, F1 & F2 INDU YASH II, ...  False
# 1                   ABHYANKAR ROAD, SITABULDI,NAGPUR  False
# 2  Shree Ganesh Bhojnalay, Manas Chowk, Sahu Colo...   True
# 3  Faasos, Plot No. 227 1, Azad Chowk, Near Gandh...  False
# 4    Shop no13 opp. Rahul hotel Ganeshpeth bus stand   True
#
#    Long Distance Delivery
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
restaurants.head(1)['Category'].values
# Out:
# array(['Biryani,Mughlai,Kebabs,Hyderabadi,North Indian,Lucknowi,Desserts,Beverages'],
#       dtype=object)

# %%
restaurants.shape
# Out:
# (1060, 10)

# %%
restaurants = restaurants[['id','Restaurant Name','Category','Rating','Area','Locality','Veg','Long Distance Delivery']]
restaurants.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                             Category  Rating  \
# 0  Biryani,Mughlai,Kebabs,Hyderabadi,North Indian...     4.1
# 1                            Sweets,Bakery,Beverages     4.6
# 2                               North Indian,Chinese     3.3
# 3  Biryani,Mughlai,Lucknowi,Hyderabadi,Kebabs,Nor...     3.9
# 4                                North Indian,Indian     4.0
#
#                 Area                       Locality    Veg  \
# 0         Khare Town                     Dharampeth  False
# 1          Sitabuldi                      SITABULDI  False
# 2           Loha Pul                 Loha Pul, Pind   True
# 3              Sadar  Azad Chowk, Near Gandhi Chowk  False
# 4  Ganeshpeth Colony                     Gandhibagh   True
#
#    Long Distance Delivery
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
restaurants.isnull().sum()
# Out:
# id                          0
# Restaurant Name             0
# Category                    0
# Rating                    638
# Area                        0
# Locality                    0
# Veg                         0
# Long Distance Delivery      0
# dtype: int64

# %%
restaurants.dropna(inplace=True)

# %%
restaurants.isnull().sum()
# Out:
# id                        0
# Restaurant Name           0
# Category                  0
# Rating                    0
# Area                      0
# Locality                  0
# Veg                       0
# Long Distance Delivery    0
# dtype: int64

# %%
restaurants.duplicated().sum()
# Out:
# 0

# %%
restaurants.iloc[0].Category
# Out:
# 'Biryani,Mughlai,Kebabs,Hyderabadi,North Indian,Lucknowi,Desserts,Beverages'

# %%
result = restaurants.dtypes
result
# Out:
# id                          int64
# Restaurant Name            object
# Category                   object
# Rating                    float64
# Area                       object
# Locality                   object
# Veg                          bool
# Long Distance Delivery      int64
# dtype: object

# %%
restaurants.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                             Category  Rating  \
# 0  [Biryani, Mughlai, Kebabs, Hyderabadi, NorthIn...     4.1
# 1                        [Sweets, Bakery, Beverages]     4.6
# 2                             [NorthIndian, Chinese]     3.3
# 3  [Biryani, Mughlai, Lucknowi, Hyderabadi, Kebab...     3.9
# 4                              [NorthIndian, Indian]     4.0
#
#                Area                   Locality    Veg  Long Distance Delivery
# 0         KhareTown                 Dharampeth  False                       0
# 1         Sitabuldi                  SITABULDI  False                       0
# 2           LohaPul               LohaPul,Pind   True                       0
# 3             Sadar  AzadChowk,NearGandhiChowk  False                       0
# 4  GaneshpethColony                 Gandhibagh   True                       0

# %%
restaurants['Category']=restaurants['Category'].apply(lambda x: [cat.strip() for cat in str(x).split(',')] if not pd.isna(x) else [])

# %%
restaurants['Category']=restaurants['Category'].apply(lambda x : [i.replace(" ","") for i in x])

# %%
restaurants['Locality'] = restaurants['Locality'].str.replace(" ", "")

# %%
restaurants['Area'] = restaurants['Area'].str.strip().str.replace(" ", "")

# %%
restaurants.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                             Category  Rating  \
# 0  [Biryani, Mughlai, Kebabs, Hyderabadi, NorthIn...     4.1
# 1                        [Sweets, Bakery, Beverages]     4.6
# 2                             [NorthIndian, Chinese]     3.3
# 3  [Biryani, Mughlai, Lucknowi, Hyderabadi, Kebab...     3.9
# 4                              [NorthIndian, Indian]     4.0
#
#                Area                   Locality    Veg  Long Distance Delivery
# 0         KhareTown                 Dharampeth  False                       0
# 1         Sitabuldi                  SITABULDI  False                       0
# 2           LohaPul               LohaPul,Pind   True                       0
# 3             Sadar  AzadChowk,NearGandhiChowk  False                       0
# 4  GaneshpethColony                 Gandhibagh   True                       0

# %%
# Convert non-string columns to strings
restaurants['Category'] = restaurants['Category'].astype(str)
restaurants['Rating'] = restaurants['Rating'].astype(str)
restaurants['Area'] = restaurants['Area'].astype(str)
restaurants['Locality'] = restaurants['Locality'].astype(str)
restaurants['Veg'] = restaurants['Veg'].astype(str)
restaurants['Distance Delivery'] = restaurants['Distance Delivery'].astype(str)

# Concatenate the columns
restaurants['tags'] = restaurants['Category'] + restaurants['Rating'].astype(str) + restaurants['Area'] + restaurants['Locality'] + restaurants['Veg'].astype(str) + restaurants['Distance Delivery'].astype(str)

# %%
restaurants.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                             Category Rating              Area  \
# 0  ['Biryani', 'Mughlai', 'Kebabs', 'Hyderabadi',...    4.1         KhareTown
# 1                  ['Sweets', 'Bakery', 'Beverages']    4.6         Sitabuldi
# 2                         ['NorthIndian', 'Chinese']    3.3           LohaPul
# 3  ['Biryani', 'Mughlai', 'Lucknowi', 'Hyderabadi...    3.9             Sadar
# 4                          ['NorthIndian', 'Indian']    4.0  GaneshpethColony
#
#                     Locality    Veg  Long Distance Delivery Distance Delivery  \
# 0                 Dharampeth  False                       0                 0
# 1                  SITABULDI  False                       0                 0
# 2               LohaPul,Pind   True                       0                 0
# 3  AzadChowk,NearGandhiChowk  False                       0                 0
# 4                 Gandhibagh   True                       0                 0
#
#                                                 tags
# 0  ['Biryani', 'Mughlai', 'Kebabs', 'Hyderabadi',...
# 1  ['Sweets', 'Bakery', 'Beverages']4.6SitabuldiS...
# 2  ['NorthIndian', 'Chinese']3.3LohaPulLohaPul,Pi...
# 3  ['Biryani', 'Mughlai', 'Lucknowi', 'Hyderabadi...
# 4  ['NorthIndian', 'Indian']4.0GaneshpethColonyGa...

# %%
new_df = restaurants[['id','Restaurant Name','tags']]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x : "".join(x))
# Out:
# <ipython-input-133-2b85a80c09e7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x : "".join(x))

# %%
new_df.head()
# Out:
#    id             Restaurant Name  \
# 0   0             Biryani By Kilo
# 1   1  Haldirams Sweets & Namkeen
# 2   2                Pind Punjabi
# 3   3             Behrouz Biryani
# 4   4        Jay Ambika Bhojnalay
#
#                                                 tags
# 0  [ ' b i r y a n i ' ,   ' m u g h l a i ' ,   ...
# 1  [ ' s w e e t s ' ,   ' b a k e r y ' ,   ' b ...
# 2  [ ' n o r t h i n d i a n ' ,   ' c h i n e s ...
# 3  [ ' b i r y a n i ' ,   ' m u g h l a i ' ,   ...
# 4  [ ' n o r t h i n d i a n ' ,   ' i n d i a n ...

# %%
new_df['tags'][0]
# Out:
# "[ ' B i r y a n i ' ,   ' M u g h l a i ' ,   ' K e b a b s ' ,   ' H y d e r a b a d i ' ,   ' N o r t h I n d i a n ' ,   ' L u c k n o w i ' ,   ' D e s s e r t s ' ,   ' B e v e r a g e s ' ] 4 . 1 K h a r e T o w n D h a r a m p e t h F a l s e 0"

# %%
new_df['tags'] = new_df['tags'].str.lower()
# Out:
# <ipython-input-137-43fbb90cc26a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].str.lower()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=10000, stop_words='english')
vector = tfidf.fit_transform(new_df['tags']).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-3f04752db13d> in <cell line: 4>()
#       2
#       3 tfidf = TfidfVectorizer(max_features=10000, stop_words='english')
# ----> 4 vector = tfidf.fit_transform(new_df['tags']).toarray()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    2131             sublinear_tf=self.sublinear_tf,
#    2132         )
# -> 2133         X = super().fit_transform(raw_documents)
#    2134         self._tfidf.fit(X)
#    2135         # X is already a transformed view of raw_documents so
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-f647df963210> in <cell line: 1>()
# ----> 1 vector = cv.fit_transform(new_df['tags']).toarray()
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1386                     break
#    1387
# -> 1388         vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1389
#    1390         if self.binary:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1292             vocabulary = dict(vocabulary)
#    1293             if not vocabulary:
# -> 1294                 raise ValueError(
#    1295                     "empty vocabulary; perhaps the documents only contain stop words"
#    1296                 )
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words
